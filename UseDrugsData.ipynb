# %% [markdown]
# <a href="https://colab.research.google.com/github/gasotoga/Phyton/blob/main/UseDrugsData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar librerias panda matlib y las de gráficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# cargar el archivo excel /content/1.4_-_Prevalence_of_drug_use_in_the_youth_population_national_data_including_NPS.xlsx
df = pd.read_excel('/content/1.4_-_Prevalence_of_drug_use_in_the_youth_population_national_data_including_NPS.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604 entries, 0 to 603
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CANNABIS USE  10 non-null     object
#  1   Unnamed: 1    21 non-null     object
#  2   Unnamed: 2    600 non-null    object
#  3   Unnamed: 3    600 non-null    object
#  4   Unnamed: 4    521 non-null    object
#  5   Unnamed: 5    446 non-null    object
#  6   Unnamed: 6    413 non-null    object
#  7   Unnamed: 7    600 non-null    object
#  8   Unnamed: 8    597 non-null    object
#  9   Unnamed: 9    235 non-null    object
# dtypes: object(10)
# memory usage: 47.3+ KB

# %%
# cargar el archivo excel con todas las hojas en el mismo df
df = pd.read_excel('/content/1.4_-_Prevalence_of_drug_use_in_the_youth_population_national_data_including_NPS.xlsx',
                   sheet_name=None)

# %%
#concatenar todo el contenido en un único df
df = pd.concat(df.values())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4183 entries, 0 to 215
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CANNABIS USE                       10 non-null     object
#  1   Unnamed: 1                         540 non-null    object
#  2   Unnamed: 2                         3937 non-null   object
#  3   Unnamed: 3                         3138 non-null   object
#  4   Unnamed: 4                         3669 non-null   object
#  5   Unnamed: 5                         2994 non-null   object
#  6   Unnamed: 6                         2445 non-null   object
#  7   Unnamed: 7                         3445 non-null   object
#  8   Unnamed: 8                         3728 non-null   object
#  9   Unnamed: 9                         2863 non-null   object
#  10  OPIOIDS USE                        12 non-null     object
# ...

# %%
# mostrar el contenido del df para los primeros 200 registros
df.head(200)
# Out:
#                    CANNABIS USE   Unnamed: 1          Unnamed: 2  \
# 0    among the youth population          NaN                 NaN
# 1       Prevalence (percentage)          NaN                 NaN
# 2                        Region    Subregion  Country/ Territory
# 3                        AFRICA  East Africa            Ethiopia
# 4                           NaN          NaN               Kenya
# ..                          ...          ...                 ...
# 195                         NaN          NaN            Colombia
# 196                         NaN          NaN            Colombia
# 197                         NaN          NaN            Colombia
# 198                         NaN          NaN             Ecuador
# 199                         NaN          NaN             Ecuador
#
#                Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6        Unnamed: 7  \
# 0                     NaN        NaN        NaN         NaN               NaN
# ...

# %%
# descripción estadística básica del df
df.describe()

# %%
# descripción de todas las columnas df con su tipo de datos
df.dtypes
# Out:
# CANNABIS USE                         object
# Unnamed: 1                           object
# Unnamed: 2                           object
# Unnamed: 3                           object
# Unnamed: 4                           object
# Unnamed: 5                           object
# Unnamed: 6                           object
# Unnamed: 7                           object
# Unnamed: 8                           object
# Unnamed: 9                           object
# OPIOIDS USE                          object
# COCAINE USE                          object
# Unnamed: 10                          object
# AMPHETAMINES USE                     object
# "Ecstasy"-type substances USE        object
# TRANQUILLIZERS and SEDATIVES USE     object
# New psychoactive substances (NPS)    object
# Unnamed: 11                          object
# Unnamed: 12                          object
# Unnamed: 13                          object
# Unnamed: 14                          object
# ...
